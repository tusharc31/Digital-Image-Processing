# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
gg = cv2.imread('../data/Image1.jpg')

# %%
import cv2 as cv
from matplotlib import pyplot as plt
image1 = cv.imread('../data/Image1.jpg')
image2 = cv.imread('../data/Image2.jpg')
plt.subplot(2, 2, 1)
plt.imshow(image1)
plt.subplot(2, 2, 2)
plt.imshow(image2)
image3 = cv.imread('../data/Image3.jpg')
image4 = cv.imread('../data/Image4.jpg')
plt.subplot(2, 2, 3)
plt.imshow(image3)
plt.subplot(2, 2, 4)
plt.imshow(image4)
plt.show()

# %%
import cv2 as cv
from matplotlib import pyplot as plt
image1 = cv.imread('../data/Image1.jpg')
image2 = cv.imread('../data/Image2.jpg')
plt.subplot(2, 2, 1)
plt.imshow(image1)
plt.axis('off')
plt.subplot(2, 2, 2)
plt.imshow(image2)
plt.axis('off')
image3 = cv.imread('../data/Image3.jpg')
image4 = cv.imread('../data/Image4.jpg')
plt.subplot(2, 2, 3)
plt.imshow(image3)
plt.axis('off')
plt.subplot(2, 2, 4)
plt.imshow(image4)
plt.axis('off')
plt.show()

# %% [markdown]
# ## ISSUE?

# %%
image1.shape
# Out:
# (570, 985, 3)

# %%
baw = np.zeros((image1.shape[0], image1.shape[1]))

# %%
baw.shape
# Out:
# (570, 985)

# %%
hehe = np.mean(image1, axis=2)

# %%
hehe.shape
# Out:
# (570, 985)

# %%
plt.imshow(hehe)

# %%
stacked_img = np.stack((hehe,)*3, axis=-1)

# %%
stacked_img.shape
# Out:
# (570, 985, 3)

# %%
stacked_img = stacked_img.astype(int)
plt.imshow(stacked_img)
cv2.imwrite("../results/black_ans_white.jpg", stacked_img)
plt.show()

# %%
plt.imshow(hehe, cmap='gray')
plt.show()

# %%
image1.shape
# Out:
# (570, 985, 3)

# %%
# import pandas as pd
# import numpy as np

# df_describe = pd.DataFrame(dataset)
# df_describe.describe()
